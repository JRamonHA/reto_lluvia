# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Obtener un df donde cada columna corresponda a un estado, el índice sea temporal para cada mes de cada año y la información muestre la lluvia acumulada en todas las estaciones.

# %%
path = 'https://smn.conagua.gob.mx/tools/RESOURCES/com_archivo_datos_resumenes/201804010000Lluv.csv'
def read_lluvia(path):
    df = pd.read_csv(path, encoding='latin-1', usecols=[2,5])
    
    df = df.groupby(by='EDO').sum()
    df = df.T

    year = path[-20:-16]
    month = path[-16:-14]
    df['time'] = pd.to_datetime(year+month, format='%Y%m')
    
    return df

# %%
data = []
fail = []
for year in range(2013,2025,1):
    for month in range(1,13,1):
        path = f'https://smn.conagua.gob.mx/tools/RESOURCES/com_archivo_datos_resumenes/{year}{month:02d}010000Lluv.csv'
        try:
            data.append(read_lluvia(path))
        except:
            fail.append(path)

# %%
len(fail)
# Out:
# 28

# %%
len(data)
# Out:
# 116

# %%
data = pd.concat(data)
data.set_index('time', inplace=True)
data.fillna(0, inplace=True)

# %%
data.columns
# Out:
# Index(['AGS', 'CAMP', 'CDMX', 'CHIH', 'CHIS', 'COAH', 'COL', 'DGO', 'GRO',
#        'GTO', 'HGO', 'JAL', 'MEX', 'MICH', 'MOR', 'NL', 'OAX', 'PUE', 'QRO',
#        'QROO', 'SIN', 'SLP', 'TAB', 'TAMP', 'TLAX', 'VER', 'YUC', 'ZAC', 'BC',
#        'BCS', 'NAY', 'SON', 'DF', 'TAMS', 'TAMPS', 'HDO'],
#       dtype='object', name='EDO')

# %%
data['CDMX'] = data.CDMX + data.DF
data['TAM'] = data.TAMP + data.TAMPS + data.TAMS
data['HGO'] = data.HDO + data.HGO
data.drop(['DF', 'TAMPS', 'TAMS', 'TAMP', 'HDO'], axis=1, inplace=True)

# %%
data
# Out:
# EDO             AGS     CAMP      CDMX     CHIH      CHIS     COAH      COL  \
# time
# 2014-11-01   269.10   459.90    457.70    14.30   4861.70   856.60  1462.20
# 2014-12-01    84.70   433.10   1072.80    14.50    861.10   149.40   148.60
# 2015-01-01   138.20  1047.10     12.90   932.30   4671.20   380.80     0.00
# 2015-02-01   763.50   333.30    101.70  1163.60   1932.80   572.70  1190.50
# 2015-03-01  2234.50  1336.00   1012.50  1621.10   3335.50  1437.30  2799.80
# ...             ...      ...       ...      ...       ...      ...      ...
# 2024-05-01    56.29   220.45   3011.29     0.01   6251.83   515.99     0.00
# 2024-06-01  1543.96  7219.49   9943.59   815.02  40684.59  1430.79  1009.30
# 2024-07-01  2360.11  2154.41  12612.26  2140.72  25003.62  1209.81  4084.11
# 2024-08-01  1010.59  3332.90  21062.23  1387.89  22681.43   574.06  3764.54
# 2024-09-01  1816.46  2980.41  14865.84   947.06  32203.33  2069.09  5248.95
#
#
# EDO          COAH          COL          DGO          GRO          GTO  ...  \
# time                                                                   ...
# 1      313.108889   176.833333   330.956667   128.372222   130.736667  ...
# 2      203.641111   298.356444   392.417778    64.922222   297.480444  ...
# 3      513.105000   298.150000   281.273000   262.150000   632.493000  ...
# 4      502.028889     0.733333   109.260000   221.655556   297.970000  ...
# 5     1164.463000    53.262000   226.627000  1669.564000  1436.713000  ...
# 6      951.967100  2069.310000  1906.296000  6737.383000  5011.675000  ...
# 7     1018.052000  2524.460200  3624.851100  6578.958000  5698.230600  ...
# 8     1231.465000  3345.584400  3109.236500  8605.389000  6608.341000  ...
# 9     2044.726100  3536.993000  3590.198001  9925.608001  4690.816000  ...
# 10     917.178667  2522.301556  1596.211778  4824.350000  1866.081333  ...
# 11     557.151200   483.904000   683.488000  1004.366000   638.872000  ...
# 12     337.844000   103.228200   285.534000   103.315000   340.901400  ...
#
# EDO           TAB         TLAX           VER          YUC          ZAC  \
# time
# 1     2871.930000    75.063333   6310.201111   821.932222   384.248889
# 2     2658.798889    34.170000   2914.585111   684.098889   536.702222
# 3     1554.869000   172.379000   4462.747000   482.662000   440.830000
# 4     1036.738889   344.938889   4039.894444   743.980000   141.128889
# 5     2029.010000   649.721000   5805.018000  1608.572000   520.142000
# 6     4844.203000  1030.523000  21117.981000  5118.197000  3125.367000
# 7     2514.311000  1057.742000  15704.426400  2685.363000  4387.410000
# 8     3694.907000  1087.777000  18205.655100  3535.494000  3320.193000
# 9     6476.000999  1097.411000  22542.357999  3725.023000  3451.403000
# 10    6688.003333   451.711111  22587.048444  2985.090000  1729.620000
# 11    5765.046000   170.940000  10602.639000  1492.508000   743.759000
# 12    2690.182000    50.552000   5261.977200   917.217000   460.229000
#
# EDO           BC          BCS          NAY          SON          TAM
# time
# 1     355.308889    83.008889    69.797778   708.796667  1003.875556
# 2     342.306667    48.147111   236.970444   667.574444   613.565556
# 3     482.589000    79.692400    88.317000   964.148000  1604.927000
# 4     100.933333     1.824444     0.524444   117.368889  2563.375556
# 5      27.375000     2.940000    27.979000    55.116000  4729.940000
# 6       1.314000   188.615000  1284.252000  1055.760200  7094.485000
# 7      35.410000   134.409200  2665.664800  3875.811000  3814.202000
# 8      98.407000   768.968200  3554.077000  4108.565000  3056.167100
# 9      94.584000  1183.956000  2966.575001  2952.318000  7673.137998
# 10     59.691111   557.051333  1415.608889  1060.982222  4539.732222
# 11    237.243000   321.052600   138.201000  1515.187000  2165.649000
# 12    356.663000    91.064200    94.892000   744.314000   705.379000
#
# [12 rows x 32 columns]

# %%
plt.figure(figsize=(15,5))
sns.heatmap(data_month, cmap='cividis')
# Out:
# <Axes: xlabel='EDO', ylabel='time'>
